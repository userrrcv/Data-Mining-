# %%
# Import the neural network model
from sklearn.neural_network import MLPClassifier

# Import evaluation metrics
from sklearn.metrics import accuracy_score, classification_report

# Initialize the Backpropagation Neural Network (MLP)
# hidden_layer_sizes=(10,) means one hidden layer with 10 neurons
# max_iter defines how many iterations the model will run
# random_state ensures reproducibility
bpn = MLPClassifier(
    hidden_layer_sizes=(10,),
    max_iter=500,
    random_state=42
)

# Train the model using the scaled training data
# X_train_scaled contains the features
# y_train contains the labels (not scaled)
bpn.fit(X_train_scaled, y_train)

# Make predictions on the test set
y_pred = bpn.predict(X_test_scaled)

# Evaluate model performance using accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))

# Print a detailed classification report (precision, recall, f1-score)
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 20
#      11 bpn = MLPClassifier(
#      12     hidden_layer_sizes=(10,),
#      13     max_iter=500,
#      14     random_state=42
#      15 )
#      17 # Train the model using the scaled training data
#      18 # X_train_scaled contains the features
#      19 # y_train contains the labels (not scaled)
# ---> 20 bpn.fit(X_train_scaled, y_train)
#      22 # Make predictions on the test set
#      23 y_pred = bpn.predict(X_test_scaled)
#
# NameError: name 'X_train_scaled' is not defined
